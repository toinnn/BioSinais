# %% [markdown]
# <a href="https://colab.research.google.com/github/toinnn/BioSinais/blob/master/mne__test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mne
# !pip install pytorch-pretrained-bert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 63.3 MB/s eta 0:00:00
# ...

# %%
import mne

# %%
import numpy as np
print("olaaa")
import mne
path = "/content/drive/MyDrive/mne_test/A01E.gdf"
pathb = "/content/drive/MyDrive/mne_test/B0101T.gdf"
raw=mne.io.read_raw_gdf(pathb)
print("olaaa2")
print(raw)#to_data_frame().keys()
events_A, event_id_A = mne.events_from_annotations(raw)
print(f"events_A : \n{events_A}")
print( f"event_id_A : \n{event_id_A}")
raw.plot(block = False ,start=5, duration=10)
# Out:
# olaaa
# Extracting EDF parameters from /content/drive/MyDrive/mne_test/B0101T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG:C3, EEG:Cz, EEG:C4, EOG:ch01, EOG:ch02, EOG:ch03
# Creating raw.info structure...
# <ipython-input-4-6ca9180a7278>:6: RuntimeWarning: Highpass cutoff frequency 100.0 is greater than lowpass cutoff frequency 0.5, setting values to 0 and Nyquist.
#   raw=mne.io.read_raw_gdf(pathb)
# olaaa2
# <RawGDF | B0101T.gdf, 6 x 604803 (2419.2 s), ~11 kB, data not loaded>
# Used Annotations descriptions: ['1023', '1077', '1078', '1079', '1081', '276', '277', '32766', '768', '769', '770']
# events_A :
# [[     0      0      8]
#  [   499      0      6]
#  [ 16749      0      7]
#  [ 32999      0      5]
#  [ 37999      0      4]
#  [ 42999      0      3]
#  [ 47999      0      2]
#  [ 52251      0      8]
#  [ 55139      0      9]
#  [ 55889      0     10]
# ...

# %%
print(raw.annotations)
# Out:
# <Annotations | 271 segments: 1023 (18), 1077 (1), 1078 (1), 1079 (1), 1081 ...>
